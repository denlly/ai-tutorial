# %% [markdown]
# ## 学习目标
# 通过数据科学在商业分析中的基础应用在这个项目，学习使用python导入，预览，分析，报表。从而对趋势进行观察。
#
# ## 使用到的知识点
# 1. Pandas
# 1. numpy
# 1. matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## 读取数据

# %%
df = pd.read_csv("./data/Titanic_train.csv")

# %% [markdown]
# ## 数据检查

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.iloc[1,:]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                           38
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %% [markdown]
# ### 用图表来检查数据

# %% [markdown]
# 建立一个柱状图显示每列中有多少个数据缺失

# %%
# isnull 
# isnan
# 显示一个柱状图
df.isnull().sum().plot(kind="barh")

# %% [markdown]
# 哪个列缺的数据最多，缺多少

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 执行数据清洗 Cabin列为 NaN 的行

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dropna(subset=["Embarked"], inplace = True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 将cabins列的缺失数据改成 ':D'

# %%
df.fillna(value=':D', inplace=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                               Heikkinen, Miss. Laina  female  26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                             Allen, Mr. William Henry    male  35      0
# 5                                     Moran, Mr. James    male  :D      0
# 6                              McCarthy, Mr. Timothy J    male  54      0
# 7                       Palsson, Master. Gosta Leonard    male   2      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4      1
# 11                            Bonnell, Miss. Elizabeth  female  58      0
# 12                      Saundercock, Mr. William Henry    male  20      0
# 13                         Andersson, Mr. Anders Johan    male  39      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55      0
# 16                                Rice, Master. Eugene    male   2      4
# 17                        Williams, Mr. Charles Eugene    male  :D      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31      1
# 19                             Masselmani, Mrs. Fatima  female  :D      0
# 20                                Fynney, Mr. Joseph J    male  35      0
# 21                               Beesley, Mr. Lawrence    male  34      0
# 22                         McGowan, Miss. Anna "Annie"  female  15      0
# 23                        Sloper, Mr. William Thompson    male  28      0
# 24                       Palsson, Miss. Torborg Danira  female   8      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38      1
# 26                             Emir, Mr. Farred Chehab    male  :D      0
# 27                      Fortune, Mr. Charles Alexander    male  19      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female  :D      0
# 29                                 Todoroff, Mr. Lalio    male  :D      0
# ..                                                 ...     ...  ..    ...
# 861                        Giles, Mr. Frederick Edward    male  21      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female  :D      8
# 864                             Gill, Mr. John William    male  24      0
# 865                           Bystrom, Mrs. (Karolina)  female  42      0
# 866                       Duran y More, Miss. Asuncion  female  27      1
# 867               Roebling, Mr. Washington Augustus II    male  31      0
# 868                        van Melkebeke, Mr. Philemon    male  :D      0
# 869                    Johnson, Master. Harold Theodor    male   4      1
# 870                                  Balkic, Mr. Cerin    male  26      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47      1
# 872                           Carlsson, Mr. Frans Olof    male  33      0
# 873                        Vander Cruyssen, Mr. Victor    male  47      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20      0
# 877                               Petroff, Mr. Nedelio    male  19      0
# 878                                 Laleff, Mr. Kristo    male  :D      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25      0
# 881                                 Markun, Mr. Johann    male  33      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22      0
# 883                      Banfield, Mr. Frederick James    male  28      0
# 884                             Sutehall, Mr. Henry Jr    male  25      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39      0
# 886                              Montvila, Rev. Juozas    male  27      0
# 887                       Graham, Miss. Margaret Edith  female  19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  :D      1
# 889                              Behr, Mr. Karl Howell    male  26      0
# 890                                Dooley, Mr. Patrick    male  32      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500           :D        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250           :D        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500           :D        S
# 5        0            330877    8.4583           :D        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750           :D        S
# 8        2            347742   11.1333           :D        S
# 9        0            237736   30.0708           :D        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500           :D        S
# 13       5            347082   31.2750           :D        S
# 14       0            350406    7.8542           :D        S
# 15       0            248706   16.0000           :D        S
# 16       1            382652   29.1250           :D        Q
# 17       0            244373   13.0000           :D        S
# 18       0            345763   18.0000           :D        S
# 19       0              2649    7.2250           :D        C
# 20       0            239865   26.0000           :D        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292           :D        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750           :D        S
# 25       5            347077   31.3875           :D        S
# 26       0              2631    7.2250           :D        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792           :D        Q
# 29       0            349216    7.8958           :D        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000           :D        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500           :D        S
# 864      0            233866   13.0000           :D        S
# 865      0            236852   13.0000           :D        S
# 866      0     SC/PARIS 2149   13.8583           :D        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000           :D        S
# 869      1            347742   11.1333           :D        S
# 870      0            349248    7.8958           :D        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000           :D        S
# 874      0         P/PP 3381   24.0000           :D        C
# 875      0              2667    7.2250           :D        C
# 876      0              7534    9.8458           :D        S
# 877      0            349212    7.8958           :D        S
# 878      0            349217    7.8958           :D        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000           :D        S
# 881      0            349257    7.8958           :D        S
# 882      0              7552   10.5167           :D        S
# 883      0  C.A./SOTON 34068   10.5000           :D        S
# 884      0   SOTON/OQ 392076    7.0500           :D        S
# 885      5            382652   29.1250           :D        Q
# 886      0            211536   13.0000           :D        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500           :D        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500           :D        Q
#
# [889 rows x 12 columns]

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## 处理列数据

# %% [markdown]
# 1. 有两列是关于多少家人同时在船上的，找出这两列并相加，相加的列的名字是"FamilyCount"

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["FamilyCount"]=df["SibSp"] + df["Parch"]

# %%
df["FamilyCount"].value_counts() # 最多一个是是10个人的家庭一起坐船
# Out:
# 0     535
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: FamilyCount, dtype: int64

# %% [markdown]
# 2. 找出牧师，这个牧师的名字当中有 Rev 字样，根据这个信息，创建一个列"IsReverend" 1 牧师 0不是牧师

# %%
df["IsReverend"] = df.Name.str.contains("Rev").map(lambda x: int(x))
# or
# df.Name.str.contains("Rev").map(lambda x: 1 if x else 0)
# or
# df.Name.str.contains("Rev").map(lambda x: int(x)) [TODO: 返回结果不一致]

# %%
df["IsReverend"].value_counts()
# Out:
# 0    883
# 1      6
# Name: IsReverend, dtype: int64

# %% [markdown]
#  为了进行分类，需要把"Embarked"一列信息分成N列, N = Embarked.Enum.count ,例如城市S,C,Q
#  同理，可以对 sex 分为三列

# %%
# df = pd.get_dummies(df, columns=["Embarked"])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilyCount  IsReverend
# 0      0         A/5 21171   7.2500   NaN        S            1           0
# 1      0          PC 17599  71.2833   C85        C            1           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S            0           0
# 3      0            113803  53.1000  C123        S            1           0
# 4      0            373450   8.0500   NaN        S            0           0

# %%
# 列表解析式
df["title"] = [name.split(',')[1].split('.')[0] for name in df.Name]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilyCount  IsReverend  \
# 0      0         A/5 21171   7.2500   NaN        S            1           0
# 1      0          PC 17599  71.2833   C85        C            1           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S            0           0
# 3      0            113803  53.1000  C123        S            1           0
# 4      0            373450   8.0500   NaN        S            0           0
#
#    title
# 0     Mr
# 1    Mrs
# 2   Miss
# 3    Mrs
# 4     Mr

# %% [markdown]
# ## EDA
# exploratory data analysis

# %% [markdown]
# 1. 所有人的存活率

# %%
df["Survived"].mean()
# Out:
# 0.38245219347581555

# %% [markdown]
# 2. 哪个性别的生存率最高

# %%
df.groupby(["Sex"])['Survived'].mean()
#df.head()
# Out:
# Sex
# female    0.740385
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# 3. 不同舱位的的生存率是多少

# %%
df.groupby(["Pclass"])["Survived"].mean()
# Out:
# Pclass
# 1    0.626168
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# 4. 有几个牧师生还

# %%
df[df.Name.str.contains("Rev.") == True]["Survived"].mean()
# Out:
# 0.0

# %% [markdown]
# 5. 以“：D” 标记的有多少人生还？比例是多少？

# %%
mask = (df["Cabin"] == ':D')
df[mask]["Survived"].mean()
# Out:
# nan

# %% [markdown]
# 6. 没有age记录的人生存率是多少 [TODO]

# %%
df[df.Age.isna() == True]['Survived'].mean() # 结果不正确
# Out:
# 0.2937853107344633

# %% [markdown]
# 7. 每个港口上船的人生存率

# %%
for embark in ["Embarked_C","Embarked_Q","Embarked_S"]:
    print(embark + " survival rate:")
    print(df[embark].mean())
    print()
# Out:
# Embarked_C survival rate:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Embarked_C'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-8f27bf1d0a91> in <module>
#       1 for embark in ["Embarked_C","Embarked_Q","Embarked_S"]:
#       2     print(embark + " survival rate:")
# ----> 3     print(df[embark].mean())
#       4     print()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Embarked_C'

# %% [markdown]
# 8. 每个仓位的儿童（age<12）生存率是？

# %%
df[int(df['Age']) < 12]["Survived"].mean()

# %% [markdown]
# 9. 船长生还了吗，他在表格里吗？

# %%
df[df.Name.str.contains('Capt')]

# %% [markdown]
# 10. 去世的人里最贵的船票是多少钱？

# %%
df[df.Survived == 0]["Fare"].max()

# %% [markdown]
# 11. 有家人生存情况变高还是变低

# %%
print(df[df['FamilyCount']>0]['Survived'].mean())
print(df[df['FamilyCount']==0]['Survived'].mean())

# %% [markdown]
# ### 绘图
# 20岁的生还率

# %%
df[df['Age']<=20]["Survived"].hist()/

# %%
df[df["Sex"]=='female']["Survived"].hist()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot = True)
